# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow
from mlflow.models import infer_signature

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
X,y=datasets.load_iris(return_X_y=True)
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.20)
params={"penalty":'l2',  "random_state": 8888, "solver":'lbfgs', "max_iter":1000, "multi_class":'auto'}

# %%
lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=8888)

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([1, 0, 2, 1, 0, 1, 1, 0, 2, 0, 0, 0, 2, 2, 1, 0, 1, 2, 0, 0, 2, 1,
#        2, 0, 1, 2, 2, 2, 2, 1])

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9666666666666667

# %%
#ML FLOW tracking
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# create a new mlflow experiment
mlflow.set_registry_uri("MLflow quickstart")

#start mlflow run
with mlflow.start_run():
    #log hyperparameters
    mlflow.log_params(params)
    #log performance metrics
    mlflow.log_metric("accuracy",accuracy)

    #set a tag for the exp
    mlflow.set_tag("Training info","Basic LR model for iris dataset")

    #infer model signature
    signature= infer_signature(X_train,lr.predict(X_train))

    # log model

    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_example=X_train,
        registered_model_name="tracking"
    )
# Out:
# Successfully registered model 'tracking'.
# Created version '1' of model 'tracking'.
# 2024/10/24 21:34:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run fearless-wren-543 at: http://127.0.0.1:5000/#/experiments/0/runs/4585202bbcf049d391f2cce416b9058c.
# 2024/10/24 21:34:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0.

# %%
#second experiment
params={"random_state": 1000, "solver":'newton-cg', "max_iter":1000, "multi_class":'auto'}
lr=LogisticRegression(**params)
lr.fit(X_train,y_train)
# Out:
# /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=1000, multi_class='auto', random_state=1000,
#                    solver='newton-cg')

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, 0, 2, 2, 1, 2, 0, 2, 0, 0, 0, 1, 2, 0, 0, 1, 1, 0, 1, 1,
#        2, 0, 1, 2, 1, 1, 0, 0])

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9666666666666667

# %%
#ML FLOW tracking
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# create a new mlflow experiment
mlflow.set_registry_uri("MLflow quickstart")

#start mlflow run
with mlflow.start_run():
    #log hyperparameters
    mlflow.log_params(params)
    #log performance metrics
    mlflow.log_metric("accuracy",accuracy)

    #set a tag for the exp
    mlflow.set_tag("Training info","Basic LR model for iris dataset")

    #infer model signatu re
    signature= infer_signature(X_train,lr.predict(X_train))

    # log model

    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_example=X_train,
        registered_model_name="tracking"
    )
# Out:
# Registered model 'tracking' already exists. Creating a new version of this model...
# Created version '2' of model 'tracking'.
# 2024/10/24 21:42:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run secretive-koi-821 at: http://127.0.0.1:5000/#/experiments/0/runs/68c5fda4d61f439f8f7cf172982e3e04.
# 2024/10/24 21:42:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0.

# %% [markdown]
# ## Inferencing and validating model

# %%
from mlflow.models import validate_serving_input

model_uri = 'runs:/68c5fda4d61f439f8f7cf172982e3e04/iris_model'

# The model is logged with an input example. MLflow converts
# it into the serving payload format for the deployed model endpoint,
# and saves it to 'serving_input_payload.json'
serving_payload = """{
  "inputs": [
    [
      5.5,
      3.5,
      1.3,
      0.2
    ],
    [
      6.3,
      2.5,
      5.0,
      1.9
    ],
    [
      5.8,
      2.7,
      3.9,
      1.2
    ],
    [
      4.8,
      3.4,
      1.9,
      0.2
    ],
    [
      4.3,
      3.0,
      1.1,
      0.1
    ],
    [
      5.5,
      2.4,
      3.7,
      1.0
    ],
    [
      6.7,
      3.0,
      5.0,
      1.7
    ],
    [
      5.4,
      3.4,
      1.5,
      0.4
    ],
    [
      5.5,
      2.4,
      3.8,
      1.1
    ],
    [
      6.1,
      2.6,
      5.6,
      1.4
    ],
    [
      5.7,
      3.0,
      4.2,
      1.2
    ],
    [
      6.7,
      3.3,
      5.7,
      2.1
    ],
    [
      6.7,
      3.0,
      5.2,
      2.3
    ],
    [
      5.1,
      3.5,
      1.4,
      0.2
    ],
    [
      4.6,
      3.4,
      1.4,
      0.3
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      5.4,
      3.0,
      4.5,
      1.5
    ],
    [
      6.1,
      3.0,
      4.9,
      1.8
    ],
    [
      6.5,
      2.8,
      4.6,
      1.5
    ],
    [
      4.6,
      3.2,
      1.4,
      0.2
    ],
    [
      4.9,
      3.0,
      1.4,
      0.2
    ],
    [
      5.0,
      3.5,
      1.3,
      0.3
    ],
    [
      5.2,
      4.1,
      1.5,
      0.1
    ],
    [
      7.6,
      3.0,
      6.6,
      2.1
    ],
    [
      5.1,
      3.5,
      1.4,
      0.3
    ],
    [
      4.9,
      3.1,
      1.5,
      0.1
    ],
    [
      5.6,
      2.8,
      4.9,
      2.0
    ],
    [
      5.2,
      2.7,
      3.9,
      1.4
    ],
    [
      5.7,
      2.5,
      5.0,
      2.0
    ],
    [
      6.4,
      3.1,
      5.5,
      1.8
    ],
    [
      6.3,
      3.4,
      5.6,
      2.4
    ],
    [
      4.4,
      3.0,
      1.3,
      0.2
    ],
    [
      6.7,
      3.3,
      5.7,
      2.5
    ],
    [
      7.0,
      3.2,
      4.7,
      1.4
    ],
    [
      6.6,
      3.0,
      4.4,
      1.4
    ],
    [
      6.9,
      3.1,
      4.9,
      1.5
    ],
    [
      5.5,
      4.2,
      1.4,
      0.2
    ],
    [
      4.4,
      3.2,
      1.3,
      0.2
    ],
    [
      6.2,
      3.4,
      5.4,
      2.3
    ],
    [
      6.8,
      2.8,
      4.8,
      1.4
    ],
    [
      7.7,
      3.0,
      6.1,
      2.3
    ],
    [
      7.4,
      2.8,
      6.1,
      1.9
    ],
    [
      6.7,
      3.1,
      4.7,
      1.5
    ],
    [
      5.6,
      2.7,
      4.2,
      1.3
    ],
    [
      6.3,
      2.9,
      5.6,
      1.8
    ],
    [
      6.0,
      2.2,
      4.0,
      1.0
    ],
    [
      6.9,
      3.2,
      5.7,
      2.3
    ],
    [
      5.7,
      2.9,
      4.2,
      1.3
    ],
    [
      6.7,
      2.5,
      5.8,
      1.8
    ],
    [
      5.2,
      3.4,
      1.4,
      0.2
    ],
    [
      6.4,
      3.2,
      5.3,
      2.3
    ],
    [
      7.7,
      2.8,
      6.7,
      2.0
    ],
    [
      5.1,
      3.8,
      1.9,
      0.4
    ],
    [
      6.1,
      3.0,
      4.6,
      1.4
    ],
    [
      5.0,
      3.2,
      1.2,
      0.2
    ],
    [
      6.4,
      2.9,
      4.3,
      1.3
    ],
    [
      5.0,
      2.0,
      3.5,
      1.0
    ],
    [
      6.9,
      3.1,
      5.1,
      2.3
    ],
    [
      4.9,
      2.5,
      4.5,
      1.7
    ],
    [
      7.7,
      2.6,
      6.9,
      2.3
    ],
    [
      5.8,
      2.7,
      4.1,
      1.0
    ],
    [
      5.6,
      2.5,
      3.9,
      1.1
    ],
    [
      6.5,
      3.2,
      5.1,
      2.0
    ],
    [
      6.2,
      2.9,
      4.3,
      1.3
    ],
    [
      5.0,
      3.0,
      1.6,
      0.2
    ],
    [
      4.7,
      3.2,
      1.3,
      0.2
    ],
    [
      5.7,
      3.8,
      1.7,
      0.3
    ],
    [
      6.3,
      2.3,
      4.4,
      1.3
    ],
    [
      5.9,
      3.2,
      4.8,
      1.8
    ],
    [
      5.1,
      3.8,
      1.5,
      0.3
    ],
    [
      7.9,
      3.8,
      6.4,
      2.0
    ],
    [
      4.8,
      3.1,
      1.6,
      0.2
    ],
    [
      6.1,
      2.9,
      4.7,
      1.4
    ],
    [
      4.8,
      3.0,
      1.4,
      0.1
    ],
    [
      5.6,
      2.9,
      3.6,
      1.3
    ],
    [
      5.3,
      3.7,
      1.5,
      0.2
    ],
    [
      6.3,
      3.3,
      6.0,
      2.5
    ],
    [
      5.1,
      3.4,
      1.5,
      0.2
    ],
    [
      6.5,
      3.0,
      5.2,
      2.0
    ],
    [
      5.5,
      2.5,
      4.0,
      1.3
    ],
    [
      5.4,
      3.4,
      1.7,
      0.2
    ],
    [
      7.2,
      3.6,
      6.1,
      2.5
    ],
    [
      6.1,
      2.8,
      4.7,
      1.2
    ],
    [
      5.6,
      3.0,
      4.5,
      1.5
    ],
    [
      6.4,
      2.7,
      5.3,
      1.9
    ],
    [
      4.7,
      3.2,
      1.6,
      0.2
    ],
    [
      5.4,
      3.9,
      1.3,
      0.4
    ],
    [
      6.6,
      2.9,
      4.6,
      1.3
    ],
    [
      6.9,
      3.1,
      5.4,
      2.1
    ],
    [
      5.8,
      4.0,
      1.2,
      0.2
    ],
    [
      5.2,
      3.5,
      1.5,
      0.2
    ],
    [
      6.7,
      3.1,
      4.4,
      1.4
    ],
    [
      6.4,
      2.8,
      5.6,
      2.1
    ],
    [
      6.0,
      2.2,
      5.0,
      1.5
    ],
    [
      4.8,
      3.4,
      1.6,
      0.2
    ],
    [
      6.4,
      2.8,
      5.6,
      2.2
    ],
    [
      6.8,
      3.2,
      5.9,
      2.3
    ],
    [
      7.3,
      2.9,
      6.3,
      1.8
    ],
    [
      5.1,
      2.5,
      3.0,
      1.1
    ],
    [
      5.5,
      2.6,
      4.4,
      1.2
    ],
    [
      6.3,
      2.7,
      4.9,
      1.8
    ],
    [
      6.8,
      3.0,
      5.5,
      2.1
    ],
    [
      4.9,
      3.1,
      1.5,
      0.2
    ],
    [
      5.7,
      2.6,
      3.5,
      1.0
    ],
    [
      5.8,
      2.6,
      4.0,
      1.2
    ],
    [
      5.0,
      3.4,
      1.6,
      0.4
    ],
    [
      6.1,
      2.8,
      4.0,
      1.3
    ],
    [
      4.8,
      3.0,
      1.4,
      0.3
    ],
    [
      4.9,
      2.4,
      3.3,
      1.0
    ],
    [
      4.6,
      3.6,
      1.0,
      0.2
    ],
    [
      5.9,
      3.0,
      4.2,
      1.5
    ],
    [
      7.2,
      3.0,
      5.8,
      1.6
    ],
    [
      6.0,
      3.0,
      4.8,
      1.8
    ],
    [
      5.0,
      3.4,
      1.5,
      0.2
    ],
    [
      5.8,
      2.7,
      5.1,
      1.9
    ],
    [
      6.5,
      3.0,
      5.5,
      1.8
    ],
    [
      7.2,
      3.2,
      6.0,
      1.8
    ],
    [
      5.1,
      3.8,
      1.6,
      0.2
    ],
    [
      6.3,
      2.8,
      5.1,
      1.5
    ],
    [
      6.2,
      2.8,
      4.8,
      1.8
    ]
  ]
}"""

# Validate the serving payload works on the model
validate_serving_input(model_uri, serving_payload)
# Out:
# array([0, 2, 1, 0, 0, 1, 2, 0, 1, 2, 1, 2, 2, 0, 0, 2, 1, 2, 1, 0, 0, 0,
#        0, 2, 0, 0, 2, 1, 2, 2, 2, 0, 2, 1, 1, 1, 0, 0, 2, 1, 2, 2, 1, 1,
#        2, 1, 2, 1, 2, 0, 2, 2, 0, 1, 0, 1, 1, 2, 2, 2, 1, 1, 2, 1, 0, 0,
#        0, 1, 2, 0, 2, 0, 1, 0, 1, 0, 2, 0, 2, 1, 0, 2, 1, 1, 2, 0, 0, 1,
#        2, 0, 0, 1, 2, 2, 0, 2, 2, 2, 1, 1, 2, 2, 0, 1, 1, 0, 1, 0, 1, 0,
#        1, 2, 2, 0, 2, 2, 2, 0, 2, 2])

# %% [markdown]
# ## load the model for inference as a  gneric python fn model

# %%
loaded_model= mlflow.pyfunc.load_model(model_info.model_uri)
predictions= loaded_model.predict(X_test)
features= datasets.load_iris().feature_names
print(features)
result= pd.DataFrame(X_test,columns=features)
print(result.head())
result["actual"]=y_test
result["predictions"]=predictions
result.head()
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                6.0               2.9                4.5               1.5
# 1                5.7               2.8                4.5               1.3
# 2                4.9               3.6                1.4               0.1
# 3                5.0               3.6                1.4               0.2
# 4                7.7               3.8                6.7               2.2
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                6.0               2.9                4.5               1.5
# 1                5.7               2.8                4.5               1.3
# 2                4.9               3.6                1.4               0.1
# 3                5.0               3.6                1.4               0.2
# 4                7.7               3.8                6.7               2.2
#
#    actual  predictions
# 0       1            1
# 1       1            1
# 2       0            0
# 3       0            0
# 4       2            2

# %%
model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_example=X_train,
        registered_model_name="tracking"
    )
# Out:
# Registered model 'tracking' already exists. Creating a new version of this model...
# Created version '3' of model 'tracking'.

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# create a new mlflow experiment
mlflow.set_registry_uri("MLflow quickstart")

#start mlflow run
with mlflow.start_run():
    #log hyperparameters
    mlflow.log_params(params)
    #log performance metrics
    mlflow.log_metric("accuracy",0.99)

    #set a tag for the exp
    mlflow.set_tag("Training info","Basic LR model for iris dataset")

    #infer model signatu re
    signature= infer_signature(X_train,lr.predict(X_train))

    # log model

    model_info = mlflow.sklearn.log_model(
        sk_model=lr,
        artifact_path="iris_model",
        signature=signature,
        input_example=X_train,
    )
# Out:
# 2024/10/24 22:26:01 INFO mlflow.tracking._tracking_service.client: 🏃 View run monumental-gull-274 at: http://127.0.0.1:5000/#/experiments/0/runs/dac87c40973d4275a9873a13b45880b4.
# 2024/10/24 22:26:01 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/0.

# %%
model_info.model_uri
# Out:
# 'runs:/dac87c40973d4275a9873a13b45880b4/iris_model'

# %%
## Inferencing from model registry

import mlflow.sklearn
model_name= "tracking-quickstart"
model_version="1"
model_uri=f"models:/{model_name}/{model_version}"
model= mlflow.sklearn.load_model(model_uri)
model
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[14], line 7
#       5 model_version="1"
#       6 model_uri=f"models:/{model_name}/{model_version}"
# ----> 7 model= mlflow.sklearn.load_model(model_uri)
#       8 model
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/sklearn/__init__.py:633, in load_model(model_uri, dst_path)
#     598 def load_model(model_uri, dst_path=None):
#     599     """
#     600     Load a scikit-learn model from a local file or a run.
#     601
#    (...)
#     631         predictions = sk_model.predict(pandas_df)
#     632     """
# --> 633     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     634     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
#     635     _add_code_from_conf_to_system_path(local_model_path, flavor_conf)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/tracking/artifact_utils.py:108, in _download_artifact_from_uri(artifact_uri, output_path, lineage_header_info)
#     100 """
#     101 Args:
#     102     artifact_uri: The *absolute* URI of the artifact to download.
#    (...)
#     105     lineage_header_info: The model lineage header info to be consumed by lineage services.
#     106 """
#     107 root_uri, artifact_path = _get_root_uri_and_artifact_path(artifact_uri)
# --> 108 repo = get_artifact_repository(artifact_uri=root_uri)
#     110 if isinstance(repo, ModelsArtifactRepository):
#     111     return repo.download_artifacts(
#     112         artifact_path=artifact_path,
#     113         dst_path=output_path,
#     114         lineage_header_info=lineage_header_info,
#     115     )
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:132, in get_artifact_repository(artifact_uri)
#     119 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     120     """
#     121     Get an artifact repository from the registry based on the scheme of artifact_uri
#     122
#    (...)
#     130         requirements.
#     131     """
# --> 132     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/artifact/artifact_repository_registry.py:77, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      72 if repository is None:
#      73     raise MlflowException(
#      74         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      75         f"Currently registered schemes are: {list(self._registry.keys())}"
#      76     )
# ---> 77 return repository(artifact_uri)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/artifact/models_artifact_repo.py:69, in ModelsArtifactRepository.__init__(self, artifact_uri)
#      63     self.model_version = self.repo.model_version
#      64 else:
#      65     (
#      66         self.model_name,
#      67         self.model_version,
#      68         underlying_uri,
# ---> 69     ) = ModelsArtifactRepository._get_model_uri_infos(artifact_uri)
#      70     self.repo = get_artifact_repository(underlying_uri)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/artifact/models_artifact_repo.py:104, in ModelsArtifactRepository._get_model_uri_infos(uri)
#     102 client = MlflowClient(registry_uri=databricks_profile_uri)
#     103 name, version = get_model_name_and_version(client, uri)
# --> 104 download_uri = client.get_model_version_download_uri(name, version)
#     106 return (
#     107     name,
#     108     version,
#     109     add_databricks_profile_info_to_artifact_uri(download_uri, databricks_profile_uri),
#     110 )
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/tracking/client.py:4163, in MlflowClient.get_model_version_download_uri(self, name, version)
#    4118 def get_model_version_download_uri(self, name: str, version: str) -> str:
#    4119     """
#    4120     Get the download location in Model Registry for this model version.
#    4121
#    (...)
#    4161         Download URI: runs:/027d7bbe81924c5a82b3e4ce979fcab7/sklearn-model
#    4162     """
# -> 4163     return self._get_registry_client().get_model_version_download_uri(name, version)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/tracking/_model_registry/client.py:317, in ModelRegistryClient.get_model_version_download_uri(self, name, version)
#     306 def get_model_version_download_uri(self, name, version):
#     307     """Get the download location in Model Registry for this model version.
#     308
#     309     Args:
#    (...)
#     315
#     316     """
# --> 317     return self.store.get_model_version_download_uri(name, version)
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/model_registry/file_store.py:823, in FileStore.get_model_version_download_uri(self, name, version)
#     810 def get_model_version_download_uri(self, name, version) -> str:
#     811     """
#     812     Get the download location in Model Registry for this model version.
#     813     NOTE: For first version of Model Registry, since the models are not copied over to another
#    (...)
#     821         A single URI location that allows reads for downloading.
#     822     """
# --> 823     model_version = self._fetch_file_model_version_if_exists(name, version)
#     824     return model_version.storage_location or model_version.source
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/model_registry/file_store.py:783, in FileStore._fetch_file_model_version_if_exists(self, name, version)
#     781 _validate_model_name(name)
#     782 _validate_model_version(version)
# --> 783 registered_model_version_dir = self._get_model_version_dir(name, version)
#     784 if not exists(registered_model_version_dir):
#     785     raise MlflowException(
#     786         f"Model Version (name={name}, version={version}) not found",
#     787         RESOURCE_DOES_NOT_EXIST,
#     788     )
#
# File /media/hashif/DATA/materials/ml_flow/venv/lib/python3.11/site-packages/mlflow/store/model_registry/file_store.py:561, in FileStore._get_model_version_dir(self, name, version)
#     559 registered_model_path = self._get_registered_model_path(name)
#     560 if not exists(registered_model_path):
# --> 561     raise MlflowException(
#     562         f"Registered Model with name={name} not found",
#     563         RESOURCE_DOES_NOT_EXIST,
#     564     )
#     565 return join(registered_model_path, f"version-{version}")
#
# MlflowException: Registered Model with name=tracking-quickstart not found
